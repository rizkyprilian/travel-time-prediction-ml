# %% [markdown]
# ### GeoSpatial Data

# %% [markdown]
# GeoSpatial data is a representation of position on the earth surface. The datapoints itself usually accompanied by metadata (such as time, format, etc) so that it can be interpreted correctly.

# %% [markdown]
# ---

# %%
import numpy as np
import pandas as pd
import geopandas as gpd
import re
from sqlalchemy import create_engine
from sqlalchemy.types import Integer, Text, String, DateTime, Float, TIMESTAMP

# %% [markdown]
# ### Raw Dataset

# %% [markdown]
# Our working datasets is three csv files:
#
# - **raw_data_2.csv** consist of gps data trajectory of 300+ vehicles during April month. GPS trajectory has minimum 60s interval

# %% [markdown]
# ## Part 1. Fixing DataTypes for GPS Trajectory

# %%
# filesize is 1.7GB, setting low_memory=False to override memory limit default setting 
df = pd.read_csv('Datasets/raw_data_2.csv', sep=';', low_memory=False)

# %%
df.head(3)
# Out:
#    record_id  device_id license_plate        driver vehicle_group  \
# 0        1.0   792168.0      B9922SDB  HARI PERMANA    DC Kawasan
# 1        2.0   792168.0      B9922SDB  HARI PERMANA    DC Kawasan
# 2        3.0   792168.0      B9922SDB  HARI PERMANA    DC Kawasan
#
#                        date      time speed_kmh   source  \
# 0  Wednesday, April 1, 2020  00:05:05         0  Program
# 1  Wednesday, April 1, 2020  00:15:05         0  Program
# 2  Wednesday, April 1, 2020  00:25:05         0  Program
#
#                    type  ...  course distance_km  odometer      region route  \
# 0  Location Information  ...     NaN         NaN  12313,48  DC Kawasan   NaN
# 1  Location Information  ...     NaN           0  12313,48  DC Kawasan   NaN
# 2  Location Information  ...     NaN           0  12313,48  DC Kawasan   NaN
#
#   altitude_m accu_voltage unit  \
# 0       37.0          NaN  NaN
# 1       37.0          NaN  NaN
# 2       37.0          NaN  NaN
#
#                                              address  Unnamed: 24
# 0  Kawasan Industri Pulo Gadung, Jakarta, Dki Jak...          NaN
# 1  Kawasan Industri Pulo Gadung, Jakarta, Dki Jak...          NaN
# 2  Kawasan Industri Pulo Gadung, Jakarta, Dki Jak...          NaN
#
# [3 rows x 25 columns]

# %% [markdown]
# ### Feature Description

# %% [markdown]
# - **device_id** : identifier of each gps receiver
# - **license_plate** : license plate of the vehicle
# - **driver** : driver name
# - **vehicle_group** : vehicle group (defined by customer)
# - **date** : date of which this point is recorded (utc+7)
# - **time** : time of which this point is recorded (utc+7)
# - **speed_kmh** : current speed of the vehicle
# - **source** : source of data (whether from hardware or software inferred)
# - **type** : Location Mark
# - **value** : Value of the event (if applicable)
# - **longitude**
# - **latitude**
# - **idling_duration_s**
# - **ignition_duration_s**
# - **course** : vehicle bearing (0-360)
# - **distance_km**
# - **odometer**
# - **region** : name of region (if the vehicle is inside a predefined geofence)
# - **route**
# - **altitude_m** : current altitude from sea level
# - **accu_voltage**
# - **unit**
# - **address**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7132129 entries, 0 to 7132128
# Data columns (total 25 columns):
# record_id              float64
# device_id              float64
# license_plate          object
# driver                 object
# vehicle_group          object
# date                   object
# time                   object
# speed_kmh              object
# source                 object
# type                   object
# value                  float64
# longitude              object
# latitude               object
# idling_duration_s      object
# ignition_duration_s    object
# course                 object
# distance_km            object
# odometer               object
# region                 object
# route                  float64
# altitude_m             float64
# accu_voltage           float64
# unit                   float64
# address                object
# Unnamed: 24            float64
# dtypes: float64(8), object(17)
# memory usage: 1.3+ GB

# %%
df.isna().sum()
# Out:
# record_id                    1
# device_id                    1
# license_plate                1
# driver                   70381
# vehicle_group                1
# date                         1
# time                         1
# speed_kmh                    1
# source                       1
# type                         1
# value                  7132129
# longitude                    1
# latitude                     1
# idling_duration_s         2965
# ignition_duration_s       2965
# course                 1616285
# distance_km               6189
# odometer                  5826
# region                 5629655
# route                  7132129
# altitude_m              134935
# accu_voltage           7132129
# unit                   7132129
# address                    816
# Unnamed: 24            7132129
# dtype: int64

# %%
df[df['device_id'].isna()]
# each datapoint must have device id
# Out:
#          record_id  device_id license_plate driver vehicle_group date time  \
# 7132128        NaN        NaN           NaN    NaN           NaN  NaN  NaN
#
#         speed_kmh source type  ...  course distance_km odometer region route  \
# 7132128       NaN    NaN  NaN  ...     NaN   432404,16      NaN    NaN   NaN
#
#         altitude_m accu_voltage unit address  Unnamed: 24
# 7132128        NaN          NaN  NaN     NaN          NaN
#
# [1 rows x 25 columns]

# %%
df.drop(7132128, inplace=True)

# %%
# discard record_id
df.drop(['record_id', 'Unnamed: 24'], axis=1, inplace=True)

# %% [markdown]
# ***Some feature data type have to be converted***

# %%
# device id supposed to be a string
df['device_id'] = df['device_id'].astype(int).astype(str)

# %%
# speed supposed to be float
df['speed_kmh'] = df.apply(lambda x: float(x['speed_kmh'].replace(',','.')), axis=1)

# %%
df.head(1)['longitude']
# Out:
# 0    106,911575
# Name: longitude, dtype: object

# %%
df.head(1)['latitude']
# Out:
# 0    -6,188440
# Name: latitude, dtype: object

# %%
# long and lat supposed to be float.

df['longitude'] = df.apply(lambda x: float(x['longitude'].replace(',','.')), axis=1)
df['latitude'] = df.apply(lambda x: float(x['latitude'].replace(',','.')), axis=1)

# %%
day_ptn = re.compile(r"(\d+)d", flags=re.I)
hour_ptn = re.compile(r"(\d+)h", flags=re.I)
min_ptn = re.compile(r"(\d+)m", flags=re.I)
sec_ptn = re.compile(r"(\d+)s", flags=re.I)

def convert_prettytime_to_seconds (_str):
    
    if _str is None:
        return 0
    elif (isinstance(_str, str)):
        _str = _str.strip()
    
        if len(_str) == 0:
            return 0

        seconds = 0

        for t_bits in _str.split():
            if re.search(day_ptn, t_bits) is not None:
                seconds += int(re.findall(day_ptn, t_bits)[0]) * 86400
            elif re.search(hour_ptn, t_bits) is not None:
                seconds += int(re.findall(hour_ptn, t_bits)[0]) * 3600
            elif re.search(min_ptn, t_bits) is not None:
                seconds += int(re.findall(min_ptn, t_bits)[0]) * 60
            elif re.search(sec_ptn, t_bits) is not None:
                seconds += int(re.findall(sec_ptn, t_bits)[0])
            else:
                raise Exception("Unable to parse time format")
                break

        return seconds
    else:
        return 0

# %%
# idling_duration_s and ignition_duration_s

df['idling_duration_s'] = df.apply(lambda x: convert_prettytime_to_seconds(x['idling_duration_s']), axis = 1)

# %%
df['ignition_duration_s'] = df.apply(lambda x: convert_prettytime_to_seconds(x['ignition_duration_s']), axis = 1)

# %%
# convert distance_km to float
df['distance_km'] = df.apply(lambda x: float(x['distance_km'].replace(',','.') if isinstance(x['distance_km'], str) else x['distance_km']), axis=1)

# %%
# convert odometer to float
df['odometer'] = df.apply(lambda x: float(x['odometer'].replace(',','.') if isinstance(x['odometer'], str) else x['odometer']), axis=1)

# %%
# convert route to object
# df.apply(lambda x: x['route'] if np.isnan(x['route']) else str(x['route']) , axis =1)
df['route'] = df.apply(lambda x: x['route'] if np.isnan(x['route']) else str(x['route']) , axis =1)

# %%
# convert course to float as well. do not treat NaN value. course 0 means true north

def format_course(x):
    if type(x['course']) == float:
        return x['course']
    elif isinstance(x['course'], str):
        return float(x['course'].replace(',','.'))
    else:
        return x['course']

# df.apply(format_course, axis=1)

df['course'] = df.apply(format_course, axis=1)

# %% [markdown]
# ### Convert time to timestamp format

# %%
df['combined_time_str'] = df['date'].astype(str) + ' ' + df['time'].astype(str) + ' ' + '+07:00'

# %%
df.head(5)
# Out:
#   device_id license_plate        driver vehicle_group  \
# 0    792168      B9922SDB  HARI PERMANA    DC Kawasan
# 1    792168      B9922SDB  HARI PERMANA    DC Kawasan
# 2    792168      B9922SDB  HARI PERMANA    DC Kawasan
# 3    792168      B9922SDB  HARI PERMANA    DC Kawasan
# 4    792168      B9922SDB  HARI PERMANA    DC Kawasan
#
#                        date      time  speed_kmh   source  \
# 0  Wednesday, April 1, 2020  00:05:05        0.0  Program
# 1  Wednesday, April 1, 2020  00:15:05        0.0  Program
# 2  Wednesday, April 1, 2020  00:25:05        0.0  Program
# 3  Wednesday, April 1, 2020  00:35:05        0.0  Program
# 4  Wednesday, April 1, 2020  00:45:05        0.0  Program
#
#                    type  value  ...  course  distance_km  odometer  \
# 0  Location Information    NaN  ...     NaN          NaN  12313.48
# 1  Location Information    NaN  ...     NaN          0.0  12313.48
# 2  Location Information    NaN  ...     NaN          0.0  12313.48
# 3  Location Information    NaN  ...     NaN          0.0  12313.48
# 4  Location Information    NaN  ...     NaN          0.0  12313.48
#
#        region  route  altitude_m  accu_voltage unit  \
# 0  DC Kawasan    NaN        37.0           NaN  NaN
# 1  DC Kawasan    NaN        37.0           NaN  NaN
# 2  DC Kawasan    NaN        37.0           NaN  NaN
# 3  DC Kawasan    NaN        37.0           NaN  NaN
# 4  DC Kawasan    NaN        37.0           NaN  NaN
#
#                                              address  \
# 0  Kawasan Industri Pulo Gadung, Jakarta, Dki Jak...
# 1  Kawasan Industri Pulo Gadung, Jakarta, Dki Jak...
# 2  Kawasan Industri Pulo Gadung, Jakarta, Dki Jak...
# 3  Kawasan Industri Pulo Gadung, Jakarta, Dki Jak...
# 4  Kawasan Industri Pulo Gadung, Jakarta, Dki Jak...
#
#                           combined_time_str
# 0  Wednesday, April 1, 2020 00:05:05 +07:00
# 1  Wednesday, April 1, 2020 00:15:05 +07:00
# 2  Wednesday, April 1, 2020 00:25:05 +07:00
# 3  Wednesday, April 1, 2020 00:35:05 +07:00
# 4  Wednesday, April 1, 2020 00:45:05 +07:00
#
# [5 rows x 24 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7132128 entries, 0 to 7132127
# Data columns (total 24 columns):
# device_id              object
# license_plate          object
# driver                 object
# vehicle_group          object
# date                   object
# time                   object
# speed_kmh              float64
# source                 object
# type                   object
# value                  float64
# longitude              float64
# latitude               float64
# idling_duration_s      int64
# ignition_duration_s    int64
# course                 float64
# distance_km            float64
# odometer               float64
# region                 object
# route                  float64
# altitude_m             float64
# accu_voltage           float64
# unit                   float64
# address                object
# combined_time_str      object
# dtypes: float64(11), int64(2), object(11)
# memory usage: 1.3+ GB

# %%
for i in df['combined_time_str'].sample(5).values:
    print(i, '--->' ,pd.to_datetime(i), '::', pd.to_datetime(i).utcoffset())

# oh my, it works. I am cryiingggg...
# Out:
# Monday, April 13, 2020 13:41:23 +07:00 ---> 2020-04-13 13:41:23+07:00 :: 7:00:00
# Wednesday, April 1, 2020 22:36:47 +07:00 ---> 2020-04-01 22:36:47+07:00 :: 7:00:00
# Wednesday, April 22, 2020 13:45:54 +07:00 ---> 2020-04-22 13:45:54+07:00 :: 7:00:00
# Friday, April 17, 2020 08:27:26 +07:00 ---> 2020-04-17 08:27:26+07:00 :: 7:00:00
# Saturday, April 4, 2020 21:28:20 +07:00 ---> 2020-04-04 21:28:20+07:00 :: 7:00:00

# %%
t = pd.to_datetime('Thursday, April 16, 2020 18:19:24 +07:00')
print(t.utcoffset())
print(t.timestamp())
print(t.day)
# Out:
# 7:00:00
# 1587035964.0
# 16

# %%
df['datetime'] = pd.to_datetime(df['combined_time_str'])

# %%
df['posix_time'] = df.apply(lambda x: x['datetime'].timestamp(), axis = 1) 
df['hour'] = df.apply(lambda x: x['datetime'].hour, axis = 1)
df['day_in_month'] = df.apply(lambda x: x['datetime'].day, axis = 1)
df['day_of_week'] = df.apply(lambda x: x['datetime'].dayofweek, axis = 1)

# %%
df.drop(['combined_time_str'], axis=1, inplace=True)

# %% [markdown]
# ### Handling Missing data

# %%
df.isna().sum()
# Out:
# device_id                    0
# license_plate                0
# driver                   70380
# vehicle_group                0
# date                         0
# time                         0
# speed_kmh                    0
# source                       0
# type                         0
# value                  7132128
# longitude                    0
# latitude                     0
# idling_duration_s            0
# ignition_duration_s          0
# course                 1616284
# distance_km               6189
# odometer                  5825
# region                 5629654
# route                  7132128
# altitude_m              134934
# accu_voltage           7132128
# unit                   7132128
# address                    815
# datetime                     0
# posix_time                   0
# hour                         0
# day_in_month                 0
# day_of_week                  0
# dtype: int64

# %%
#fill NaN distance to 0

df[df['distance_km'].isna()].head(100)
# Out:
#        device_id license_plate         driver vehicle_group  \
# 0         792168      B9922SDB   HARI PERMANA    DC Kawasan
# 32648     792173      B9909SDB       YULIANTO    DC Kawasan
# 53005     792173      B9909SDB       YULIANTO    DC Kawasan
# 55462     792173      B9909SDB       YULIANTO    DC Kawasan
# 55464     792173      B9909SDB       YULIANTO    DC Kawasan
# ...          ...           ...            ...           ...
# 492377   1019950      B9340SDB  BAGUS NUGRAHA   DC Cikarang
# 528013   1019951       B9176HZ         FAISAL   DC Cikarang
# 563372   1019952      B9896SDB         WASONO   DC Cikarang
# 603286   1019953       T8626DD  TEGUH RIYANTO   DC Cikarang
# 629468   1019954       T8624DD    ITA CASMITA   DC Cikarang
#
#                              date      time  speed_kmh   source  \
# 0        Wednesday, April 1, 2020  00:05:05        0.0  Program
# 32648    Wednesday, April 1, 2020  00:06:36        0.0  Program
# 53005   Wednesday, April 22, 2020  06:45:50        0.0  Program
# 55462      Friday, April 24, 2020  06:26:19        0.0  Program
# 55464      Friday, April 24, 2020  06:40:03        0.0  Program
# ...                           ...       ...        ...      ...
# 492377   Wednesday, April 1, 2020  00:01:03        0.0  Program
# 528013   Wednesday, April 1, 2020  00:08:54        0.0  Program
# 563372   Wednesday, April 1, 2020  00:08:12        0.0  Program
# 603286   Wednesday, April 1, 2020  00:02:26        0.0  Program
# 629468   Wednesday, April 1, 2020  00:08:54        0.0  Program
#
#                         type  value  ...  route  altitude_m  accu_voltage  \
# 0       Location Information    NaN  ...    NaN        37.0           NaN
# 32648   Location Information    NaN  ...    NaN        10.0           NaN
# 53005   Location Information    NaN  ...    NaN        12.0           NaN
# 55462   Location Information    NaN  ...    NaN        30.0           NaN
# 55464   Location Information    NaN  ...    NaN        30.0           NaN
# ...                      ...    ...  ...    ...         ...           ...
# 492377  Location Information    NaN  ...    NaN        65.0           NaN
# 528013  Location Information    NaN  ...    NaN        67.0           NaN
# 563372  Location Information    NaN  ...    NaN        60.0           NaN
# 603286  Location Information    NaN  ...    NaN        61.0           NaN
# 629468  Location Information    NaN  ...    NaN        73.0           NaN
#
#         unit                                            address  \
# 0        NaN  Kawasan Industri Pulo Gadung, Jakarta, Dki Jak...
# 32648    NaN  Kawasan Industri Pulo Gadung, Jakarta, Dki Jak...
# 53005    NaN  Kawasan Industri Pulo Gadung, Jakarta, Dki Jak...
# 55462    NaN  Kawasan Industri Pulo Gadung, Jakarta, Dki Jak...
# 55464    NaN  Kawasan Industri Pulo Gadung, Jakarta, Dki Jak...
# ...      ...                                                ...
# 492377   NaN                      Bekasi, Jawa Barat, Indonesia
# 528013   NaN                      Bekasi, Jawa Barat, Indonesia
# 563372   NaN                      Bekasi, Jawa Barat, Indonesia
# 603286   NaN                      Bekasi, Jawa Barat, Indonesia
# 629468   NaN                      Bekasi, Jawa Barat, Indonesia
#
#                         datetime    posix_time hour  day_in_month  day_of_week
# 0      2020-04-01 00:05:05+07:00  1.585674e+09    0             1            2
# 32648  2020-04-01 00:06:36+07:00  1.585674e+09    0             1            2
# 53005  2020-04-22 06:45:50+07:00  1.587513e+09    6            22            2
# 55462  2020-04-24 06:26:19+07:00  1.587684e+09    6            24            4
# 55464  2020-04-24 06:40:03+07:00  1.587685e+09    6            24            4
# ...                          ...           ...  ...           ...          ...
# 492377 2020-04-01 00:01:03+07:00  1.585674e+09    0             1            2
# 528013 2020-04-01 00:08:54+07:00  1.585675e+09    0             1            2
# 563372 2020-04-01 00:08:12+07:00  1.585674e+09    0             1            2
# 603286 2020-04-01 00:02:26+07:00  1.585674e+09    0             1            2
# 629468 2020-04-01 00:08:54+07:00  1.585675e+09    0             1            2
#
# [100 rows x 28 columns]

# %%
#fill NaN odometer to 0
df[df['odometer'].isna()].sample(50).apply(print, axis=1)
# Out:
# device_id                                                        1021536
# license_plate                                                    B9418VJ
# driver                                                        JAYADI K.W
# vehicle_group                                               DC P Kambing
# date                                              Tuesday, April 7, 2020
# time                                                            01:57:20
# speed_kmh                                                              0
# source                                                           Program
# type                                                Location Information
# value                                                                NaN
# longitude                                                        106.909
# latitude                                                        -6.19618
# idling_duration_s                                                      0
# ignition_duration_s                                                    0
# course                                                               NaN
# distance_km                                                          NaN
# odometer                                                             NaN
# region                                                               NaN
# route                                                                NaN
# altitude_m                                                            35
# accu_voltage                                                         NaN
# unit                                                                 NaN
# address                Kawasan Industri Pulo Gadung, Jalan Pulo Kambi...
# datetime                                       2020-04-07 01:57:20+07:00
# posix_time                                                    1.5862e+09
# hour                                                                   1
# day_in_month                                                           7
# day_of_week                                                            1
# Name: 6904141, dtype: object
# device_id                                                        1021344
# license_plate                                                   B9411SDC
# driver                                                            AMIN M
# vehicle_group                                                 DC Kawasan
# date                                            Thursday, April 30, 2020
# time                                                            08:03:32
# speed_kmh                                                              0
# source                                                           Program
# type                                                Location Information
# value                                                                NaN
# longitude                                                        106.911
# latitude                                                        -6.18811
# idling_duration_s                                                      0
# ignition_duration_s                                                    0
# course                                                               NaN
# distance_km                                                          NaN
# odometer                                                             NaN
# region                                                        DC Kawasan
# route                                                                NaN
# altitude_m                                                            26
# accu_voltage                                                         NaN
# unit                                                                 NaN
# address                Kawasan Industri Pulo Gadung, Jakarta, Dki Jak...
# datetime                                       2020-04-30 08:03:32+07:00
# posix_time                                                   1.58821e+09
# hour                                                                   8
# day_in_month                                                          30
# day_of_week                                                            3
# Name: 3131114, dtype: object
# device_id                                                        1021536
# license_plate                                                    B9418VJ
# driver                                                        JAYADI K.W
# vehicle_group                                               DC P Kambing
# date                                             Thursday, April 9, 2020
# time                                                            14:27:13
# speed_kmh                                                              0
# source                                                           Program
# type                                                Location Information
# value                                                                NaN
# longitude                                                        106.909
# latitude                                                        -6.19618
# idling_duration_s                                                      0
# ignition_duration_s                                                    0
# course                                                               NaN
# distance_km                                                          NaN
# odometer                                                             NaN
# region                                                               NaN
# route                                                                NaN
# altitude_m                                                            35
# accu_voltage                                                         NaN
# unit                                                                 NaN
# address                Kawasan Industri Pulo Gadung, Jalan Pulo Kambi...
# datetime                                       2020-04-09 14:27:13+07:00
# posix_time                                                   1.58642e+09
# hour                                                                  14
# day_in_month                                                           9
# day_of_week                                                            3
# Name: 6904504, dtype: object
# device_id                                                        1021327
# license_plate                                                   B9912SDB
# driver                                                       FAIZAL HADI
# vehicle_group                                                 DC Kawasan
# date                                            Thursday, April 30, 2020
# time                                                            07:19:46
# speed_kmh                                                              0
# source                                                           Program
# type                                                Location Information
# value                                                                NaN
# longitude                                                        106.912
# latitude                                                        -6.18859
# idling_duration_s                                                      0
# ignition_duration_s                                                    0
# course                                                               NaN
# distance_km                                                          NaN
# odometer                                                             NaN
# region                                                        DC Kawasan
# route                                                                NaN
# altitude_m                                                            22
# accu_voltage                                                         NaN
# unit                                                                 NaN
# address                Kawasan Industri Pulo Gadung, Jakarta, Dki Jak...
# datetime                                       2020-04-30 07:19:46+07:00
# posix_time                                                   1.58821e+09
# hour                                                                   7
# day_in_month                                                          30
# day_of_week                                                            3
# Name: 2868194, dtype: object
# device_id                                                        1021536
# license_plate                                                    B9418VJ
# driver                                                        JAYADI K.W
# vehicle_group                                               DC P Kambing
# date                                            Thursday, April 16, 2020
# time                                                            05:47:13
# speed_kmh                                                              0
# source                                                               Log
# type                                                Location Information
# value                                                                NaN
# longitude                                                        106.909
# latitude                                                        -6.19618
# idling_duration_s                                                      0
# ignition_duration_s                                                    0
# course                                                               NaN
# distance_km                                                          NaN
# odometer                                                             NaN
# region                                                               NaN
# route                                                                NaN
# altitude_m                                                            35
# accu_voltage                                                         NaN
# unit                                                                 NaN
# address                Kawasan Industri Pulo Gadung, Jalan Pulo Kambi...
# datetime                                       2020-04-16 05:47:13+07:00
# posix_time                                                   1.58699e+09
# hour                                                                   5
# day_in_month                                                          16
# day_of_week                                                            3
# Name: 6905466, dtype: object
# device_id                                                        1021529
# license_plate                                                   B9926SDB
# driver                                                        BENEDIKTUS
# vehicle_group                                               DC P Kambing
# date                                             Saturday, April 4, 2020
# time                                                            12:53:53
# speed_kmh                                                              0
# source                                                           Program
# type                                                Location Information
# value                                                                NaN
# longitude                                                        106.906
# latitude                                                        -6.19322
# idling_duration_s                                                      0
# ignition_duration_s                                                    0
# course                                                               NaN
# distance_km                                                          NaN
# odometer                                                             NaN
# region                                                               NaN
# route                                                                NaN
# altitude_m                                                            33
# accu_voltage                                                         NaN
# unit                                                                 NaN
# address                Jalan Pulo Lio, 13930 Jakarta, Dki Jakarta, In...
# datetime                                       2020-04-04 12:53:53+07:00
# posix_time                                                   1.58598e+09
# hour                                                                  12
# day_in_month                                                           4
# day_of_week                                                            5
# Name: 6853463, dtype: object
# device_id                                                        1021536
# license_plate                                                    B9418VJ
# driver                                                        JAYADI K.W
# vehicle_group                                               DC P Kambing
# date                                              Tuesday, April 7, 2020
# time                                                            00:27:21
# speed_kmh                                                              0
# source                                                           Program
# type                                                Location Information
# value                                                                NaN
# longitude                                                        106.909
# latitude                                                        -6.19618
# idling_duration_s                                                      0
# ignition_duration_s                                                    0
# course                                                               NaN
# distance_km                                                          NaN
# odometer                                                             NaN
# region                                                               NaN
# route                                                                NaN
# altitude_m                                                            35
# accu_voltage                                                         NaN
# unit                                                                 NaN
# address                Kawasan Industri Pulo Gadung, Jalan Pulo Kambi...
# datetime                                       2020-04-07 00:27:21+07:00
# posix_time                                                   1.58619e+09
# hour                                                                   0
# day_in_month                                                           7
# day_of_week                                                            1
# Name: 6904132, dtype: object
# device_id                                                        1021536
# license_plate                                                    B9418VJ
# driver                                                        JAYADI K.W
# vehicle_group                                               DC P Kambing
# date                                              Tuesday, April 7, 2020
# time                                                            04:17:21
# speed_kmh                                                              0
# source                                                           Program
# type                                                Location Information
# value                                                                NaN
# longitude                                                        106.909
# latitude                                                        -6.19618
# idling_duration_s                                                      0
# ignition_duration_s                                                    0
# course                                                               NaN
# distance_km                                                          NaN
# odometer                                                             NaN
# region                                                               NaN
# route                                                                NaN
# altitude_m                                                            35
# accu_voltage                                                         NaN
# unit                                                                 NaN
# address                Kawasan Industri Pulo Gadung, Jalan Pulo Kambi...
# datetime                                       2020-04-07 04:17:21+07:00
# posix_time                                                   1.58621e+09
# hour                                                                   4
# day_in_month                                                           7
# day_of_week                                                            1
# Name: 6904155, dtype: object
# device_id                                                        1021536
# license_plate                                                    B9418VJ
# driver                                                        JAYADI K.W
# vehicle_group                                               DC P Kambing
# date                                              Friday, April 17, 2020
# time                                                            03:07:11
# speed_kmh                                                              0
# source                                                           Program
# type                                                Location Information
# value                                                                NaN
# longitude                                                        106.909
# latitude                                                        -6.19618
# idling_duration_s                                                      0
# ignition_duration_s                                                    0
# course                                                               NaN
# distance_km                                                          NaN
# odometer                                                             NaN
# region                                                               NaN
# route                                                                NaN
# altitude_m                                                            35
# accu_voltage                                                         NaN
# unit                                                                 NaN
# address                Kawasan Industri Pulo Gadung, Jalan Pulo Kambi...
# datetime                                       2020-04-17 03:07:11+07:00
# posix_time                                                   1.58707e+09
# hour                                                                   3
# day_in_month                                                          17
# day_of_week                                                            4
# Name: 6905594, dtype: object
# device_id                                                        1021536
# license_plate                                                    B9418VJ
# driver                                                        JAYADI K.W
# vehicle_group                                               DC P Kambing
# date                                            Saturday, April 11, 2020
# time                                                            08:17:07
# speed_kmh                                                              0
# source                                                           Program
# type                                                Location Information
# value                                                                NaN
# longitude                                                        106.909
# latitude                                                        -6.19618
# idling_duration_s                                                      0
# ignition_duration_s                                                    0
# course                                                               NaN
# distance_km                                                          NaN
# odometer                                                             NaN
# region                                                               NaN
# route                                                                NaN
# altitude_m                                                            35
# accu_voltage                                                         NaN
# unit                                                                 NaN
# address                Kawasan Industri Pulo Gadung, Jalan Pulo Kambi...
# datetime                                       2020-04-11 08:17:07+07:00
# posix_time                                                   1.58657e+09
# hour                                                                   8
# day_in_month                                                          11
# day_of_week                                                            5
# Name: 6904755, dtype: object
# device_id                                                        1021536
# license_plate                                                    B9418VJ
# driver                                                        JAYADI K.W
# vehicle_group                                               DC P Kambing
# date                                           Wednesday, April 15, 2020
# time                                                            11:36:55
# speed_kmh                                                              0
# source                                                           Program
# type                                                Location Information
# value                                                                NaN
# longitude                                                        106.909
# latitude                                                        -6.19618
# idling_duration_s                                                    756
# ignition_duration_s                                                  755
# course                                                               NaN
# distance_km                                                          NaN
# odometer                                                             NaN
# region                                                               NaN
# route                                                                NaN
# altitude_m                                                            35
# accu_voltage                                                         NaN
# unit                                                                 NaN
# address                Kawasan Industri Pulo Gadung, Jalan Pulo Kambi...
# datetime                                       2020-04-15 11:36:55+07:00
# posix_time                                                   1.58693e+09
# hour                                                                  11
# day_in_month                                                          15
# day_of_week                                                            2
# Name: 6905355, dtype: object
# device_id                                                        1021298
# license_plate                                                   B9947SDB
# driver                                                           SARBINI
# vehicle_group                                                 DC Kawasan
# date                                              Friday, April 10, 2020
# time                                                            10:26:19
# speed_kmh                                                              0
# source                                                           Program
# type                                                Location Information
# value                                                                NaN
# longitude                                                        106.911
# latitude                                                        -6.18863
# idling_duration_s                                                      0
# ignition_duration_s                                                    0
# course                                                               NaN
# distance_km                                                          NaN
# odometer                                                             NaN
# region                                                        DC Kawasan
# route                                                                NaN
# altitude_m                                                            41
# accu_voltage                                                         NaN
# unit                                                                 NaN
# address                Kawasan Industri Pulo Gadung, Jakarta, Dki Jak...
# datetime                                       2020-04-10 10:26:19+07:00
# posix_time                                                   1.58649e+09
# hour                                                                  10
# day_in_month                                                          10
# day_of_week                                                            4
# Name: 2226574, dtype: object
# device_id                                                        1021282
# license_plate                                                    B9446VJ
# driver                                                            YONO S
# vehicle_group                                                 DC Ciputat
# date                                              Monday, April 27, 2020
# time                                                            11:16:06
# speed_kmh                                                           9.13
# source                                                           Program
# type                                                Location Information
# value                                                                NaN
# longitude                                                        106.807
# latitude                                                        -6.25297
# idling_duration_s                                                      0
# ignition_duration_s                                                    0
# course                                                            281.42
# distance_km                                                          NaN
# odometer                                                             NaN
# region                          CPT_IOD KANTOR PENGHUB.PEMDA PROP.JATENG
# route                                                                NaN
# altitude_m                                                            28
# accu_voltage                                                         NaN
# unit                                                                 NaN
# address                Jalan Darmawangsa Viii, 12160 Jakarta, Dki Jak...
# datetime                                       2020-04-27 11:16:06+07:00
# posix_time                                                   1.58796e+09
# hour                                                                  11
# day_in_month                                                          27
# day_of_week                                                            0
# Name: 1947156, dtype: object
# device_id                                                        1021362
# license_plate                                                   B9204SDC
# driver                                                WANDA AHMAD DAHLAN
# vehicle_group                                                 DC Kawasan
# date                                              Friday, April 17, 2020
# time                                                            13:13:54
# speed_kmh                                                              0
# source                                                           Program
# type                                                Location Information
# value                                                                NaN
# longitude                                                        106.911
# latitude                                                        -6.18837
# idling_duration_s                                                      0
# ignition_duration_s                                                    0
# course                                                               NaN
# distance_km                                                          NaN
# odometer                                                             NaN
# region                                                        DC Kawasan
# route                                                                NaN
# altitude_m                                                            34
# accu_voltage                                                         NaN
# unit                                                                 NaN
# address                Kawasan Industri Pulo Gadung, Jakarta, Dki Jak...
# datetime                                       2020-04-17 13:13:54+07:00
# posix_time                                                    1.5871e+09
# hour                                                                  13
# day_in_month                                                          17
# day_of_week                                                            4
# Name: 3356387, dtype: object
# device_id                                                        1021529
# license_plate                                                   B9926SDB
# driver                                                        BENEDIKTUS
# vehicle_group                                               DC P Kambing
# date                                               Sunday, April 5, 2020
# time                                                            21:53:48
# speed_kmh                                                              0
# source                                                           Program
# type                                                Location Information
# value                                                                NaN
# longitude                                                        106.906
# latitude                                                        -6.19322
# idling_duration_s                                                      0
# ignition_duration_s                                                    0
# course                                                               NaN
# distance_km                                                          NaN
# odometer                                                             NaN
# region                                                               NaN
# route                                                                NaN
# altitude_m                                                            33
# accu_voltage                                                         NaN
# unit                                                                 NaN
# address                Jalan Pulo Lio, 13930 Jakarta, Dki Jakarta, In...
# datetime                                       2020-04-05 21:53:48+07:00
# posix_time                                                    1.5861e+09
# hour                                                                  21
# day_in_month                                                           5
# day_of_week                                                            6
# Name: 6853661, dtype: object
# device_id                                                        1021282
# license_plate                                                    B9446VJ
# driver                                                            YONO S
# vehicle_group                                                 DC Ciputat
# date                                              Monday, April 27, 2020
# time                                                            10:40:29
# speed_kmh                                                           9.88
# source                                                               Log
# type                                                Location Information
# value                                                                NaN
# longitude                                                        106.803
# latitude                                                        -6.25544
# idling_duration_s                                                      0
# ignition_duration_s                                                    0
# course                                                            266.46
# distance_km                                                          NaN
# odometer                                                             NaN
# region                           CPT_IOD PT.DHARMAWANGSA RAYA/SANATORIUM
# route                                                                NaN
# altitude_m                                                            36
# accu_voltage                                                         NaN
# unit                                                                 NaN
# address                Jalan Brawijaya 1a, 12160 Jakarta, Dki Jakarta...
# datetime                                       2020-04-27 10:40:29+07:00
# posix_time                                                   1.58796e+09
# hour                                                                  10
# day_in_month                                                          27
# day_of_week                                                            0
# Name: 1947079, dtype: object
# device_id                                                        1021316
# license_plate                                                   B9236SDC
# driver                                               YUDI ENDRI SETIAWAN
# vehicle_group                                                 DC Kawasan
# date                                             Tuesday, April 14, 2020
# time                                                            11:09:37
# speed_kmh                                                              0
# source                                                           Program
# type                                                Location Information
# value                                                                NaN
# longitude                                                        106.827
# latitude                                                         -6.1672
# idling_duration_s                                                      0
# ignition_duration_s                                                    0
# course                                                               NaN
# distance_km                                                          NaN
# odometer                                                             NaN
# region                                                               NaN
# route                                                                NaN
# altitude_m                                                            26
# accu_voltage                                                         NaN
# unit                                                                 NaN
# address                Grand Brilliant Palace, Jalan Ir. H. Juanda, 1...
# datetime                                       2020-04-14 11:09:37+07:00
# posix_time                                                   1.58684e+09
# hour                                                                  11
# day_in_month                                                          14
# day_of_week                                                            1
# Name: 2589809, dtype: object
# device_id                                                        1021316
# license_plate                                                   B9236SDC
# driver                                               YUDI ENDRI SETIAWAN
# vehicle_group                                                 DC Kawasan
# date                                              Friday, April 17, 2020
# time                                                            09:37:37
# speed_kmh                                                              0
# source                                                           Program
# type                                                Location Information
# value                                                                NaN
# longitude                                                        106.911
# latitude                                                        -6.18878
# idling_duration_s                                                      0
# ignition_duration_s                                                    0
# course                                                               NaN
# distance_km                                                          NaN
# odometer                                                             NaN
# region                                                        DC Kawasan
# route                                                                NaN
# altitude_m                                                            42
# accu_voltage                                                         NaN
# unit                                                                 NaN
# address                Kawasan Industri Pulo Gadung, Jakarta, Dki Jak...
# datetime                                       2020-04-17 09:37:37+07:00
# posix_time                                                   1.58709e+09
# hour                                                                   9
# day_in_month                                                          17
# day_of_week                                                            4
# Name: 2592556, dtype: object
# device_id                                                        1019984
# license_plate                                                   B9201SDC
# driver                                                          AGUS SHM
# vehicle_group                                                 DC Ciputat
# date                                           Wednesday, April 22, 2020
# time                                                            15:30:48
# speed_kmh                                                              0
# source                                                           Program
# type                                                Location Information
# value                                                                NaN
# longitude                                                        106.775
# latitude                                                        -6.26783
# idling_duration_s                                                      0
# ignition_duration_s                                                    0
# course                                                               NaN
# distance_km                                                          NaN
# odometer                                                             NaN
# region                                                        DC Ciputat
# route                                                                NaN
# altitude_m                                                            52
# accu_voltage                                                         NaN
# unit                                                                 NaN
# address                Aqua, Jalan Pondok Pinang 5, 12310 Jakarta, Dk...
# datetime                                       2020-04-22 15:30:48+07:00
# posix_time                                                   1.58754e+09
# hour                                                                  15
# day_in_month                                                          22
# day_of_week                                                            2
# Name: 1230671, dtype: object
# device_id                                                        1021529
# license_plate                                                   B9926SDB
# driver                                                        BENEDIKTUS
# vehicle_group                                               DC P Kambing
# date                                               Monday, April 6, 2020
# time                                                            01:33:47
# speed_kmh                                                              0
# source                                                           Program
# type                                                Location Information
# value                                                                NaN
# longitude                                                        106.906
# latitude                                                        -6.19322
# idling_duration_s                                                      0
# ignition_duration_s                                                    0
# course                                                               NaN
# distance_km                                                          NaN
# odometer                                                             NaN
# region                                                               NaN
# route                                                                NaN
# altitude_m                                                            33
# accu_voltage                                                         NaN
# unit                                                                 NaN
# address                Jalan Pulo Lio, 13930 Jakarta, Dki Jakarta, In...
# datetime                                       2020-04-06 01:33:47+07:00
# posix_time                                                   1.58611e+09
# hour                                                                   1
# day_in_month                                                           6
# day_of_week                                                            0
# Name: 6853683, dtype: object
# device_id                                         1021556
# license_plate                                    BE8174YH
# driver                                            MA ARIF
# vehicle_group                                  DC Lampung
# date                               Sunday, April 19, 2020
# time                                             12:34:53
# speed_kmh                                               0
# source                                            Program
# type                                 Location Information
# value                                                 NaN
# longitude                                         105.304
# latitude                                         -5.41516
# idling_duration_s                                       0
# ignition_duration_s                                     0
# course                                                NaN
# distance_km                                           NaN
# odometer                                              NaN
# region                                                NaN
# route                                                 NaN
# altitude_m                                            NaN
# accu_voltage                                          NaN
# unit                                                  NaN
# address                Bandar Lampung, Lampung, Indonesia
# datetime                        2020-04-19 12:34:53+07:00
# posix_time                                    1.58727e+09
# hour                                                   12
# day_in_month                                           19
# day_of_week                                             6
# Name: 7079442, dtype: object
# device_id                                                        1021536
# license_plate                                                    B9418VJ
# driver                                                        JAYADI K.W
# vehicle_group                                               DC P Kambing
# date                                            Saturday, April 11, 2020
# time                                                            03:27:07
# speed_kmh                                                              0
# source                                                           Program
# type                                                Location Information
# value                                                                NaN
# longitude                                                        106.909
# latitude                                                        -6.19618
# idling_duration_s                                                      0
# ignition_duration_s                                                    0
# course                                                               NaN
# distance_km                                                          NaN
# odometer                                                             NaN
# region                                                               NaN
# route                                                                NaN
# altitude_m                                                            35
# accu_voltage                                                         NaN
# unit                                                                 NaN
# address                Kawasan Industri Pulo Gadung, Jalan Pulo Kambi...
# datetime                                       2020-04-11 03:27:07+07:00
# posix_time                                                   1.58655e+09
# hour                                                                   3
# day_in_month                                                          11
# day_of_week                                                            5
# Name: 6904726, dtype: object
# device_id                                                        1021267
# license_plate                                                   B9155SDC
# driver                                                       RONI ALPIAN
# vehicle_group                                                 DC Ciputat
# date                                              Monday, April 27, 2020
# time                                                            21:14:06
# speed_kmh                                                              0
# source                                                           Program
# type                                                Location Information
# value                                                                NaN
# longitude                                                        106.775
# latitude                                                        -6.26786
# idling_duration_s                                                      0
# ignition_duration_s                                                    0
# course                                                               NaN
# distance_km                                                          NaN
# odometer                                                             NaN
# region                                                        DC Ciputat
# route                                                                NaN
# altitude_m                                                            56
# accu_voltage                                                         NaN
# unit                                                                 NaN
# address                Rumah Kado Rini, Jalan Pondok Pinang 5, 12310 ...
# datetime                                       2020-04-27 21:14:06+07:00
# posix_time                                                     1.588e+09
# hour                                                                  21
# day_in_month                                                          27
# day_of_week                                                            0
# Name: 1679284, dtype: object
# device_id                                                        1021537
# license_plate                                                   B9783TCH
# driver                                                           SUNARTO
# vehicle_group                                               DC P Kambing
# date                                             Saturday, April 4, 2020
# time                                                            15:27:00
# speed_kmh                                                              0
# source                                                           Program
# type                                                Location Information
# value                                                                NaN
# ...
# accu_voltage                                                         NaN
# unit                                                                 NaN
# address                Jalan Wijaya Iii, 12160 Jakarta, Dki Jakarta, ...
# datetime                                       2020-04-15 08:32:35+07:00
# posix_time                                                   1.58691e+09
# hour                                                                   8
# day_in_month                                                          15
# day_of_week                                                            2
# Name: 1938791, dtype: object
# device_id                                                        1021324
# license_plate                                                   B9902SDB
# driver                                                           ROSIDIN
# vehicle_group                                                 DC Kawasan
# date                                             Tuesday, April 28, 2020
# time                                                            07:15:00
# speed_kmh                                                              0
# source                                                               Log
# type                                                Location Information
# value                                                                NaN
# longitude                                                        106.911
# latitude                                                        -6.18832
# idling_duration_s                                                      0
# ignition_duration_s                                                    0
# course                                                               NaN
# distance_km                                                          NaN
# odometer                                                             NaN
# region                                                        DC Kawasan
# route                                                                NaN
# altitude_m                                                            28
# accu_voltage                                                         NaN
# unit                                                                 NaN
# address                Kawasan Industri Pulo Gadung, Jakarta, Dki Jak...
# datetime                                       2020-04-28 07:15:00+07:00
# posix_time                                                   1.58803e+09
# hour                                                                   7
# day_in_month                                                          28
# day_of_week                                                            1
# Name: 2773425, dtype: object
# device_id                                                        1021536
# license_plate                                                    B9418VJ
# driver                                                        JAYADI K.W
# vehicle_group                                               DC P Kambing
# date                                              Monday, April 13, 2020
# time                                                            01:37:03
# speed_kmh                                                              0
# source                                                           Program
# type                                                Location Information
# value                                                                NaN
# longitude                                                        106.909
# latitude                                                        -6.19618
# idling_duration_s                                                      0
# ignition_duration_s                                                    0
# course                                                               NaN
# distance_km                                                          NaN
# odometer                                                             NaN
# region                                                               NaN
# route                                                                NaN
# altitude_m                                                            35
# accu_voltage                                                         NaN
# unit                                                                 NaN
# address                Kawasan Industri Pulo Gadung, Jalan Pulo Kambi...
# datetime                                       2020-04-13 01:37:03+07:00
# posix_time                                                   1.58672e+09
# hour                                                                   1
# day_in_month                                                          13
# day_of_week                                                            0
# Name: 6905003, dtype: object
# device_id                                                        1021536
# license_plate                                                    B9418VJ
# driver                                                        JAYADI K.W
# vehicle_group                                               DC P Kambing
# date                                             Thursday, April 9, 2020
# time                                                            03:27:15
# speed_kmh                                                              0
# source                                                           Program
# type                                                Location Information
# value                                                                NaN
# longitude                                                        106.909
# latitude                                                        -6.19618
# idling_duration_s                                                      0
# ignition_duration_s                                                    0
# course                                                               NaN
# distance_km                                                          NaN
# odometer                                                             NaN
# region                                                               NaN
# route                                                                NaN
# altitude_m                                                            35
# accu_voltage                                                         NaN
# unit                                                                 NaN
# address                Kawasan Industri Pulo Gadung, Jalan Pulo Kambi...
# datetime                                       2020-04-09 03:27:15+07:00
# posix_time                                                   1.58638e+09
# hour                                                                   3
# day_in_month                                                           9
# day_of_week                                                            3
# Name: 6904438, dtype: object
# device_id                                                        1021529
# license_plate                                                   B9926SDB
# driver                                                        BENEDIKTUS
# vehicle_group                                               DC P Kambing
# date                                               Sunday, April 5, 2020
# time                                                            11:13:49
# speed_kmh                                                              0
# source                                                           Program
# type                                                Location Information
# value                                                                NaN
# longitude                                                        106.906
# latitude                                                        -6.19322
# idling_duration_s                                                      0
# ignition_duration_s                                                    0
# course                                                               NaN
# distance_km                                                          NaN
# odometer                                                             NaN
# region                                                               NaN
# route                                                                NaN
# altitude_m                                                            33
# accu_voltage                                                         NaN
# unit                                                                 NaN
# address                Jalan Pulo Lio, 13930 Jakarta, Dki Jakarta, In...
# datetime                                       2020-04-05 11:13:49+07:00
# posix_time                                                   1.58606e+09
# hour                                                                  11
# day_in_month                                                           5
# day_of_week                                                            6
# Name: 6853597, dtype: object
# device_id                                                        1021316
# license_plate                                                   B9236SDC
# driver                                               YUDI ENDRI SETIAWAN
# vehicle_group                                                 DC Kawasan
# date                                              Monday, April 13, 2020
# time                                                            12:55:26
# speed_kmh                                                              0
# source                                                           Program
# type                                                Location Information
# value                                                                NaN
# longitude                                                        106.911
# latitude                                                        -6.18873
# idling_duration_s                                                      0
# ignition_duration_s                                                    0
# course                                                               NaN
# distance_km                                                          NaN
# odometer                                                             NaN
# region                                                        DC Kawasan
# route                                                                NaN
# altitude_m                                                            34
# accu_voltage                                                         NaN
# unit                                                                 NaN
# address                Kawasan Industri Pulo Gadung, Jakarta, Dki Jak...
# datetime                                       2020-04-13 12:55:26+07:00
# posix_time                                                   1.58676e+09
# hour                                                                  12
# day_in_month                                                          13
# day_of_week                                                            0
# Name: 2588979, dtype: object
# device_id                                                        1021536
# license_plate                                                    B9418VJ
# driver                                                        JAYADI K.W
# vehicle_group                                               DC P Kambing
# date                                               Sunday, April 5, 2020
# time                                                            08:07:27
# speed_kmh                                                              0
# source                                                           Program
# type                                                Location Information
# value                                                                NaN
# longitude                                                        106.909
# latitude                                                        -6.19618
# idling_duration_s                                                      0
# ignition_duration_s                                                    0
# course                                                               NaN
# distance_km                                                          NaN
# odometer                                                             NaN
# region                                                               NaN
# route                                                                NaN
# altitude_m                                                            35
# accu_voltage                                                         NaN
# unit                                                                 NaN
# address                Kawasan Industri Pulo Gadung, Jalan Pulo Kambi...
# datetime                                       2020-04-05 08:07:27+07:00
# posix_time                                                   1.58605e+09
# hour                                                                   8
# day_in_month                                                           5
# day_of_week                                                            6
# Name: 6903887, dtype: object
# device_id                                                        1021322
# license_plate                                                   B9226SDC
# driver                                                          SUHERMAN
# vehicle_group                                                 DC Kawasan
# date                                              Friday, April 10, 2020
# time                                                            13:20:14
# speed_kmh                                                              0
# source                                                           Program
# type                                                Location Information
# value                                                                NaN
# longitude                                                        106.911
# latitude                                                        -6.18854
# idling_duration_s                                                      0
# ignition_duration_s                                                    0
# course                                                               NaN
# distance_km                                                          NaN
# odometer                                                             NaN
# region                                                               NaN
# route                                                                NaN
# altitude_m                                                            39
# accu_voltage                                                         NaN
# unit                                                                 NaN
# address                Kawasan Industri Pulo Gadung, Jakarta, Dki Jak...
# datetime                                       2020-04-10 13:20:14+07:00
# posix_time                                                    1.5865e+09
# hour                                                                  13
# day_in_month                                                          10
# day_of_week                                                            4
# Name: 2713443, dtype: object
# 6904141    None
# 3131114    None
# 6904504    None
# 2868194    None
# 6905466    None
# 6853463    None
# 6904132    None
# 6904155    None
# 6905594    None
# 6904755    None
# 6905355    None
# 2226574    None
# 1947156    None
# 3356387    None
# 6853661    None
# 1947079    None
# 2589809    None
# 2592556    None
# 1230671    None
# 6853683    None
# 7079442    None
# 6904726    None
# 1679284    None
# 6908681    None
# 6853537    None
# 2697491    None
# 6905287    None
# 6903945    None
# 1944041    None
# 6853396    None
# 3150641    None
# 1945102    None
# 6905435    None
# 3138421    None
# 6905620    None
# 3650517    None
# 2586712    None
# 6908859    None
# 6904266    None
# 6905428    None
# 6853545    None
# 6904994    None
# 1938791    None
# 2773425    None
# 6905003    None
# 6904438    None
# 6853597    None
# 2588979    None
# 6903887    None
# 2713443    None
# dtype: object

# %%
df[df['odometer'].isna()][['speed_kmh']].describe()
# Out:
#          speed_kmh
# count  5825.000000
# mean      0.498439
# std       2.297667
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       0.000000
# max      24.440000

# %%
df[df['distance_km'].isna()][['speed_kmh']].describe()
# Out:
#          speed_kmh
# count  6189.000000
# mean      0.479628
# std       2.258426
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       0.000000
# max      24.440000

# %%
df[(df['speed_kmh'] == 24.44) & (df['odometer'].isna())]
# Out:
#         device_id license_plate        driver vehicle_group  \
# 3155679   1021346       B9921DI  DEDE M ISHAK    DC Kawasan
#
#                            date      time  speed_kmh   source  \
# 3155679  Friday, April 24, 2020  08:35:08      24.44  Program
#
#                          type  value  ...  route  altitude_m  accu_voltage  \
# 3155679  Location Information    NaN  ...    NaN        21.0           NaN
#
#          unit                                            address  \
# 3155679   NaN  Pt Asuransi, Jalan Pemuda, 13220 Jakarta, Dki ...
#
#                          datetime    posix_time hour  day_in_month  \
# 3155679 2020-04-24 08:35:08+07:00  1.587692e+09    8            24
#
#          day_of_week
# 3155679            4
#
# [1 rows x 28 columns]

# %%
df[df['course'].isna()]
# Out:
#         device_id license_plate        driver  vehicle_group  \
# 0          792168      B9922SDB  HARI PERMANA     DC Kawasan
# 1          792168      B9922SDB  HARI PERMANA     DC Kawasan
# 2          792168      B9922SDB  HARI PERMANA     DC Kawasan
# 3          792168      B9922SDB  HARI PERMANA     DC Kawasan
# 4          792168      B9922SDB  HARI PERMANA     DC Kawasan
# ...           ...           ...           ...            ...
# 7132123   1021565      B9786TCH  Mukti Makmur  DC Rawa Domba
# 7132124   1021565      B9786TCH  Mukti Makmur  DC Rawa Domba
# 7132125   1021565      B9786TCH  Mukti Makmur  DC Rawa Domba
# 7132126   1021565      B9786TCH  Mukti Makmur  DC Rawa Domba
# 7132127   1021565      B9786TCH  Mukti Makmur  DC Rawa Domba
#
#                              date      time  speed_kmh   source  \
# 0        Wednesday, April 1, 2020  00:05:05        0.0  Program
# 1        Wednesday, April 1, 2020  00:15:05        0.0  Program
# 2        Wednesday, April 1, 2020  00:25:05        0.0  Program
# 3        Wednesday, April 1, 2020  00:35:05        0.0  Program
# 4        Wednesday, April 1, 2020  00:45:05        0.0  Program
# ...                           ...       ...        ...      ...
# 7132123  Thursday, April 30, 2020  13:51:36        0.0  Program
# 7132124  Thursday, April 30, 2020  14:01:35        0.0  Program
# 7132125  Thursday, April 30, 2020  14:11:35        0.0  Program
# 7132126  Thursday, April 30, 2020  14:21:36        0.0  Program
# 7132127  Thursday, April 30, 2020  14:31:35        0.0  Program
#
#                          type  value  ...  route  altitude_m  accu_voltage  \
# 0        Location Information    NaN  ...    NaN        37.0           NaN
# 1        Location Information    NaN  ...    NaN        37.0           NaN
# 2        Location Information    NaN  ...    NaN        37.0           NaN
# 3        Location Information    NaN  ...    NaN        37.0           NaN
# 4        Location Information    NaN  ...    NaN        37.0           NaN
# ...                       ...    ...  ...    ...         ...           ...
# 7132123  Location Information    NaN  ...    NaN        35.0           NaN
# 7132124  Location Information    NaN  ...    NaN        35.0           NaN
# 7132125  Location Information    NaN  ...    NaN        35.0           NaN
# 7132126  Location Information    NaN  ...    NaN        35.0           NaN
# 7132127  Location Information    NaN  ...    NaN        35.0           NaN
#
#          unit                                            address  \
# 0         NaN  Kawasan Industri Pulo Gadung, Jakarta, Dki Jak...
# 1         NaN  Kawasan Industri Pulo Gadung, Jakarta, Dki Jak...
# 2         NaN  Kawasan Industri Pulo Gadung, Jakarta, Dki Jak...
# 3         NaN  Kawasan Industri Pulo Gadung, Jakarta, Dki Jak...
# 4         NaN  Kawasan Industri Pulo Gadung, Jakarta, Dki Jak...
# ...       ...                                                ...
# 7132123   NaN  Jalan Rawa Domba, 13440 Jakarta, Dki Jakarta, ...
# 7132124   NaN  Jalan Rawa Domba, 13440 Jakarta, Dki Jakarta, ...
# 7132125   NaN  Jalan Rawa Domba, 13440 Jakarta, Dki Jakarta, ...
# 7132126   NaN  Jalan Rawa Domba, 13440 Jakarta, Dki Jakarta, ...
# 7132127   NaN  Jalan Rawa Domba, 13440 Jakarta, Dki Jakarta, ...
#
#                          datetime    posix_time hour  day_in_month  \
# 0       2020-04-01 00:05:05+07:00  1.585674e+09    0             1
# 1       2020-04-01 00:15:05+07:00  1.585675e+09    0             1
# 2       2020-04-01 00:25:05+07:00  1.585676e+09    0             1
# 3       2020-04-01 00:35:05+07:00  1.585676e+09    0             1
# 4       2020-04-01 00:45:05+07:00  1.585677e+09    0             1
# ...                           ...           ...  ...           ...
# 7132123 2020-04-30 13:51:36+07:00  1.588229e+09   13            30
# 7132124 2020-04-30 14:01:35+07:00  1.588230e+09   14            30
# 7132125 2020-04-30 14:11:35+07:00  1.588231e+09   14            30
# 7132126 2020-04-30 14:21:36+07:00  1.588231e+09   14            30
# 7132127 2020-04-30 14:31:35+07:00  1.588232e+09   14            30
#
#          day_of_week
# 0                  2
# 1                  2
# 2                  2
# 3                  2
# 4                  2
# ...              ...
# 7132123            3
# 7132124            3
# 7132125            3
# 7132126            3
# 7132127            3
#
# [1616284 rows x 28 columns]

# %%
df[df['course'].isna()][['speed_kmh']].describe()
# Out:
#           speed_kmh
# count  1.616284e+06
# mean   3.729285e-02
# std    6.035708e-01
# min    0.000000e+00
# 25%    0.000000e+00
# 50%    0.000000e+00
# 75%    0.000000e+00
# max    7.056000e+01

# %% [markdown]
# Most NaN course happened when speed is 0. it makes sense

# %% [markdown]
# ## export to csv

# %%
df.to_csv('Datasets/raw_data_2_cleaned.csv')

# %% [markdown]
# on second thought, i should put this in database

# %%
# dumping all tables takes too much time, so i trimmed some of the unnecessary features
df_sql = df[['device_id',
'license_plate',
'driver',
'vehicle_group',
'speed_kmh',
'type',
'value',
'longitude',
'latitude',
'idling_duration_s',
'ignition_duration_s',
'course',
'distance_km',
'odometer',
'region',
'route',
'altitude_m',
'datetime',
'posix_time',
'hour',
'day_in_month',
'day_of_week']]

# %%
engine = create_engine('postgres+psycopg2://jcds:pwdk2020@127.0.0.1:5432/gpstrajectory')

# %%
df_sql.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7132128 entries, 74224 to 74223
# Data columns (total 22 columns):
# device_id              object
# license_plate          object
# driver                 object
# vehicle_group          object
# speed_kmh              float64
# type                   object
# value                  float64
# longitude              float64
# latitude               float64
# idling_duration_s      int64
# ignition_duration_s    int64
# course                 float64
# distance_km            float64
# odometer               float64
# region                 object
# route                  float64
# altitude_m             float64
# datetime               datetime64[ns, pytz.FixedOffset(420)]
# posix_time             float64
# hour                   int64
# day_in_month           int64
# day_of_week            int64
# dtypes: datetime64[ns, pytz.FixedOffset(420)](1), float64(10), int64(5), object(6)
# memory usage: 1.2+ GB

# %%
df_sql.sort_values(['device_id', 'datetime'], ascending=True, inplace=True)
# Out:
# /Users/rprilian/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
from sqlalchemy.types import Integer, Text, String, DateTime, Float
df_sql.to_sql("raw_trajectory",
           engine,
           if_exists='replace',
           index=True,
           chunksize=50,
           dtype={
                'device_id': String,
                'license_plate': String,
                'driver': String,
                'vehicle_group': String,
                'speed_kmh': Float,
                'type': String,
                'value': Float,
                'longitude': Float,
                'latitude': Float,
                'idling_duration_s': Integer,
                'ignition_duration_s': Integer,
                'course': Float,
                'distance_km': Float,
                'odometer': Float,
                'region': String,
                'route': String,
                'altitude_m': Float,
                'datetime': TIMESTAMP(timezone=True),
                'posix_time': Float,
                'hour': Integer,
                'day_in_month': Integer,
                'day_of_week': Integer
           })
